# %%
print("In this notebook we will learn about Funtions")
# Out:
# In this notebook we will learn about Funtions

# %% [markdown]
# # Funtion
# ## Defination:
# It is a set of block of code to perform a specific task.
