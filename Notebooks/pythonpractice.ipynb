# %%
###### question1.	Write a  program to find maximum between two numbers.

a=int(input("enter your first number"))
b=int(input("enter your second number"))
print ("maximum number ",a) if(a>b) else print ("maximum number",b)
# Out:
# enter your first number 55
# enter your second number 655
# maximum number 655

# %%
#question 2.Write a  program to find maximum between three numbers.
i=int(input("enter a number"))
j=int(input("enter a number"))
k=int(input("enter a number"))
if(i>j and i>k):
  print("maximum number is :",i)
elif(j>i and j>k):
  print("maximum number is :",j)
else:
   print("maximum number is :",k)
# Out:
# enter a number 55
# enter a number 65
# enter a number 45
# maximum number is : 65

# %%
# question 3.	Write a  program to check whether a number is negative, positive or zero.
i=int(input("enter a number"))
if(i>0):
    print("number is positive")
else:
    print("number is negative")
# Out:
# enter a number -22
# number is negative

# %%
#question 4.	Write a program to check whether a number is divisible by 5 and 11 or not.
i=int(input("enter a number"))
if(i%5==0 and i%11==0):
  print("number is divisible by 5 and 11")
else:
   print("invalid number")
# Out:
# enter a number 44
# ii

# %%
#queston 5.	Write a  program to check whether a number is even or odd.
i=int(input("enter a number"))
if(i%2==0):
   print("number is even",i)     
else:
      print("number is odd")
# Out:
# enter a number 55
# number is odd

# %%
#question 6.	Write a  program to check whether a year is leap year or not.
a=int(input("enter year"))
if (a%4==0 and a%100!=0): 
   print("leap year")
else:
    print("not a leap year")
# Out:
# enter year 2024
# leap year

# %%
#question 7.Write a program to check whether a character is alphabet or not
char=input("enter a alphabet")
if char.isalpha():
    print("the character is an alphabet")
else:
    print("the charcter is not an alphabet")

# %%
#question 8.	Write a  program to input any alphabet and check whether it is vowel or consonant.
i=input("enter a alphabet")
li=["a","e","i","o","u"]
if(i in li):
 print("vowel")
else:
   print("consonent")
# Out:
# enter a alphabet d
# consonent

# %%
#question 9.	Write a  program to input any character and check whether it is alphabet, digit or special character.
# Out:
#   File <string>:5
#     elif:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Out:
# enter a alphabet d
# d uppercase
# d lowecase

# %%
#question 10.10.	Write a program to check whether a character is uppercase or lowercase alphabet.

    
def check(ch):
    
 if (ch >= 'A' and ch <= 'Z'):
     print(ch,"is an UpperCase character")
     elif (ch >= 'a' and ch <= 'z'):
      print(ch,"is an LowerCase character")
else:
        print(ch,"is not an alphabetic character")
# Out:
#   Cell In[86], line 8
#     elif (ch >= 'a' and ch <= 'z'):
#     ^
# SyntaxError: invalid syntax

# %%
pip install numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000015934E686E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/numpy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000015934DEE850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/numpy/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000015934DEEAD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/numpy/
# ...

# %%
n=int(input("enter a number"))
count=0
i=1
while(i<=n):
    if i%n==0:
        count=count+1
if count==2:
    print("prime number")
else:
    print("composite number")
